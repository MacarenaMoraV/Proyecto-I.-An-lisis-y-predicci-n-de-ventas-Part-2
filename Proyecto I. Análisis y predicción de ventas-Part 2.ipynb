# %% [markdown]
# # 1.PREPARACIÓN DEL ENTORNO

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %% [markdown]
# #2. CARGA DE DATOS

# %%
path = "//content/drive/MyDrive/Bootcamp/BBDD/retail_sales_dataset.csv"
df = pd.read_csv(path)

# %%
df.head(10)
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
# 5               6  2023-04-25     CUST006  Female   45           Beauty
# 6               7  2023-03-13     CUST007    Male   46         Clothing
# 7               8  2023-02-22     CUST008    Male   30      Electronics
# 8               9  2023-12-13     CUST009    Male   63      Electronics
# 9              10  2023-10-07     CUST010  Female   52         Clothing
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# ...

# %% [markdown]
# # 3. EXPLORACION INICIAL DE DATOS

# %%
#Con esto visualizo las ultimas 5 filas del DataFrame
df.tail()
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120

# %%
# Acá obtengo información general del Data Frame.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
# A continuación utilizo describe() que me permite visualizar los datos estadísticos del DataFrame
df.describe().T
# Out:
#                  count     mean         std   min     25%    50%     75%  \
# Transaction ID  1000.0  500.500  288.819436   1.0  250.75  500.5  750.25
# Age             1000.0   41.392   13.681430  18.0   29.00   42.0   53.00
# Quantity        1000.0    2.514    1.132734   1.0    1.00    3.0    4.00
# Price per Unit  1000.0  179.890  189.681356  25.0   30.00   50.0  300.00
# Total Amount    1000.0  456.000  559.997632  25.0   60.00  135.0  900.00
#
#                    max
# Transaction ID  1000.0
# Age               64.0
# Quantity           4.0
# Price per Unit   500.0
# Total Amount    2000.0

# %% [markdown]
# #4. INSPECCION DE LOS DATOS

# %% [markdown]
# ° Inspeccionar los tipos de datos de cada columna utilizando el atributo dtypes.

# %%
df.dtypes
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %% [markdown]
# ° Contar los valores únicos en la columna Producto utilizando el método value_counts()

# %%
df['Product Category'].value_counts()
# Debido a que no exite la columna Producto (solo), utilicé la columna "Product Category" para visualizar lo solicitado.
# Out:
# Product Category
# Clothing       351
# Electronics    342
# Beauty         307
# Name: count, dtype: int64

# %% [markdown]
# ° Mostrar todos los valores únicos en la columna Tienda utilizando el método unique().

# %%
# Debido a que no exite la columna Tienda, utilicé la columna "Age" para visualizar lo solicitado.
df['Age'].unique()
# Out:
# array([34, 26, 50, 37, 30, 45, 46, 63, 52, 23, 35, 22, 64, 42, 19, 27, 47,
#        62, 18, 49, 28, 38, 43, 39, 44, 51, 58, 48, 55, 20, 40, 54, 36, 31,
#        21, 57, 25, 56, 29, 61, 32, 41, 59, 60, 33, 53, 24])

# %% [markdown]
# #5.FILTRADO DE DATOS

# %% [markdown]
# ° Filtrar el DataFrame para mostrar solo las filas donde las edades sean mayores a 50.

# %%
# Utilicé esa columna ya que no existe la columna solicitada "Ventas"

df_filtrado_1= df[df["Age"] > 50][["Age"]]
df_filtrado_1
# Out:
#      Age
# 8     63
# 9     52
# 13    64
# 18    62
# 24    64
# ..   ...
# 989   58
# 991   57
# 993   51
# 995   62
# 996   52
#
# [313 rows x 1 columns]

# %% [markdown]
# ° Filtrar el DataFrame para mostrar solo las filas donde "Price per Unit" sean mayores a 40.

# %%
# Utilicé esa columna ya que no existe la columna solicitada "Ventas"

df_filtrado_2= df[df["Price per Unit"] < 50][["Price per Unit"]]
df_filtrado_2
# Out:
#      Price per Unit
# 2                30
# 5                30
# 6                25
# 7                25
# 11               25
# ..              ...
# 991              30
# 994              30
# 996              30
# 997              25
# 999              30
#
# [393 rows x 1 columns]

# %% [markdown]
# ° Utilizando el método query(), filtrar el DataFrame para mostrar las filas donde el genero sea Femenino y las edades sean mayores a 30.

# %%
# De la misma manera que procedí en los anteriores ejercicios, elegí esos parámetros para el desarrollo del ejercicio

df_filtrado_3 = df.query("Gender == 'Female' & Age > 30")[["Gender", "Age"]]
df_filtrado_3
# Out:
#      Gender  Age
# 5    Female   45
# 9    Female   52
# 14   Female   42
# 17   Female   47
# 18   Female   62
# ..      ...  ...
# 991  Female   57
# 992  Female   48
# 993  Female   51
# 994  Female   41
# 998  Female   36
#
# [371 rows x 2 columns]

# %%
df.dtypes
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %% [markdown]
# #6. SLICING DE DATOS

# %% [markdown]
# ° Selecciona y muestra solo las columnas Producto y Ventas del DataFrame.

# %%
# Utilicé las columnas Transaction ID y Date, ya que no existen las columnas solicitadas
# En este caso como estoy con slicing de datos, utilizar .loc

df_slicing_1 = df.loc[:, ["Transaction ID", "Date"]]
df_slicing_1
# Out:
#      Transaction ID        Date
# 0                 1  2023-11-24
# 1                 2  2023-02-27
# 2                 3  2023-01-13
# 3                 4  2023-05-21
# 4                 5  2023-05-06
# ..              ...         ...
# 995             996  2023-05-16
# 996             997  2023-11-17
# 997             998  2023-10-29
# 998             999  2023-12-05
# 999            1000  2023-04-12
#
# [1000 rows x 2 columns]

# %% [markdown]
# ° Utilizando loc[], selecciona y muestra las filas de la 5 a la 10 (inclusive) y las columnas Producto y Tienda.

# %%
# Utilicé las columnas Transaction ID y Customer ID, ya que no existen las columnas solicitadas

df_slicing_2 = df.loc[5:10, ["Transaction ID", "Customer ID"]]
df_slicing_2
# Out:
#     Transaction ID Customer ID
# 5                6     CUST006
# 6                7     CUST007
# 7                8     CUST008
# 8                9     CUST009
# 9               10     CUST010
# 10              11     CUST011

# %% [markdown]
# ° Utilizando iloc[], selecciona y muestra las primeras 5 filas y las primeras 3 columnas del DataFrame.

# %%
df.iloc[0:5, 0:3]
# Out:
#    Transaction ID        Date Customer ID
# 0               1  2023-11-24     CUST001
# 1               2  2023-02-27     CUST002
# 2               3  2023-01-13     CUST003
# 3               4  2023-05-21     CUST004
# 4               5  2023-05-06     CUST005
